# %%
import numpy as np
import pickle
from matplotlib import pyplot as plt
# two helper functions
from HelperFunctions import TestModels,PlotModel
from tqdm import tqdm

# %%
res = TestModels(N_train=15*200,
                 N_test=15*100,
                 P=15,
                 seed=1234,
                 model='random',
                 noise=0.03
                 )

fig,axs = plt.subplots(1,2,figsize=(6,3),dpi=160)
PlotModel(res,axs)
plt.savefig("../figures/RandomLinearModel.png")
# Out:
# MAE raw 4.9660802497079235
# RMS raw 16.034503361785998
# ENV raw 0.2687113741648509
# Envelope Violation (raw): 14.3 %
# MAE Resampled 2.1044844176854998
# RMS Resampled 4.221764415496747
# ENV Resampled 0.2687113741648509
# Envelope Violation (Resampled): 14.5 %
# MAE Random 1.086360829257008
# RMS Random 1.183289007426029
# ENV Random 0.13859281750576374
# Envelope Violation (Random): 0.3 %
